# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
pd.options.display.float_format = '${:,.0f}'.format
pd.set_option('display.max_columns', None)
pd.set_option('mode.chained_assignment', None)
#pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv(r'C:\Users\Gabriel\PythonProjects\Macys\Annual 2019 DIV Cluster.csv',index_col=False)

# %%
Div19 = df[['Loc','TOTAL TSL','State','CORP VOL','REGION','CLIMATE','LIFESTYLE','CUSTOMER SEGMENTS','STORE INITIATIVES',
    'TTL Career Sls $','Tailored Sls $','Shoes Sls $','Dress Furnishings Sls $','Basic Furnishing Sls $',
    'Accessories Sls $']]

Div19['TTL Career Pen'] = (Div19['TTL Career Sls $']/(Div19['TTL Career Sls $'].sum()))
Div19['Tailored Pen'] = (Div19['Tailored Sls $']/(Div19['Tailored Sls $'].sum()))
Div19['Shoes Pen'] = (Div19['Shoes Sls $']/(Div19['Shoes Sls $'].sum()))
Div19['Dress Pen'] = (Div19['Dress Furnishings Sls $']/(Div19['Dress Furnishings Sls $'].sum()))
Div19['Basic Pen'] = (Div19['Basic Furnishing Sls $']/(Div19['Basic Furnishing Sls $'].sum()))
Div19['Acc Pen'] = (Div19['Accessories Sls $']/(Div19['Accessories Sls $'].sum()))

col = ['TTL Career Pen','Tailored Pen','Shoes Pen','Dress Pen','Basic Pen','Acc Pen']
Div19 = Div19.rename(columns={
       'TTL Career Sls $':'TTL Career $','Tailored Sls $':'Tailored $',
       'Shoes Sls $':'Shoes $','Dress Furnishings Sls $':'Dress $',
       'Basic Furnishing Sls $':'Basic $', 'Accessories Sls $':'Acc $'})
#col1 = ['Loc','TOTAL TSL','State','CORP VOL','REGION','CLIMATE','LIFESTYLE','CUSTOMER SEGMENTS','STORE INITIATIVES',
#    'TTL Career Sls $','TTL Career Pen','Tailored Sls $','Tailored Pen','Shoes Sls $','Shoes Pen','Dress Furnishings Sls $',
#        'Dress Pen','Basic Furnishing Sls $','Basic Pen','Accessories Sls $','Acc Pen']

# %%
for x in col:
    Div19[x] = Div19[x].map("{:,.2%}".format)

# %%
col1 = ['TTL Career $','Tailored $','Shoes $','Dress $','Basic $','Acc $','Loc']
col2 = ['A++','A+','A','B','C','D','E','F','G']
vg = Div19.pivot_table(index='CORP VOL',values=['TTL Career $','Tailored $','Shoes $','Dress $','Basic $','Acc $','Loc'],
                       aggfunc={'TTL Career $':np.sum,'Tailored $':np.sum,'Shoes $':np.sum,'Dress $':np.sum,'Basic $':np.sum,'Acc $':np.sum,
                                'Loc':len}
                      ).reindex(col2)
vg = vg[col1]
vg['TTL Career Pen'] = vg['TTL Career $'].cumsum() / vg['TTL Career $'].sum()
vg['Tailored Pen'] = vg['Tailored $'].cumsum() / vg['Tailored $'].sum()
vg['Shoes Pen'] = vg['Shoes $'].cumsum() / vg['Shoes $'].sum()
vg['Dress Pen'] = vg['Dress $'].cumsum() / vg['Dress $'].sum()
vg['Basic Pen'] = vg['Basic $'].cumsum() / vg['Basic $'].sum()
vg['Acc Pen'] = vg['Acc $'].cumsum() / vg['Acc $'].sum()
for x in col:
    vg[x] = vg[x].map("{:.2%}".format)
col3 = ['TTL Career $', 'Tailored $', 'Shoes $', 'Dress $', 'Basic $', 'Acc $',
       'TTL Career Pen','Loc', 'Tailored Pen','Loc' 'Shoes Pen', 'Dress Pen',
       'Basic Pen', 'Acc Pen']
vg
# Out:
#           TTL Career $  Tailored $  Shoes $  Dress $  Basic $   Acc $  Loc  \
# CORP VOL
# A++            $56,170     $16,947  $12,644   $8,277  $12,360  $5,942    1
# A+             $87,286     $32,292  $17,063  $14,660  $17,439  $5,832    9
# A             $118,230     $42,086  $24,127  $20,785  $22,873  $8,360   16
# B             $309,983    $121,686  $54,280  $56,886  $55,497 $21,634   63
# C             $194,342     $76,367  $32,154  $37,390  $34,626 $13,805   57
# D             $122,730     $44,785  $20,801  $23,619  $24,243  $9,283   52
# E             $181,446     $66,551  $28,583  $36,904  $35,088 $14,319  109
# F             $162,548     $56,875  $25,944  $34,778  $31,095 $13,855  158
# G              $34,275     $11,493   $5,401   $7,174   $7,123  $3,084   49
#
#          TTL Career Pen Tailored Pen Shoes Pen Dress Pen Basic Pen  Acc Pen
# CORP VOL
# A++               4.43%        3.61%     5.72%     3.44%     5.14%    6.18%
# ...

# %% [markdown]
# #### Dress with CORP VG is about 4% lower than other depts from A+ to E Vol. Will identify which store has opportunities and challenges.

# %%
col1 = ['TTL Career $','Tailored $','Shoes $','Dress $','Basic $','Acc $','Loc']
#col2 = ['A++','A+','A','B','C','D','E','F','G']
region = Div19.pivot_table(index='REGION',values=['TTL Career $','Tailored $','Shoes $','Dress $','Basic $','Acc $','Loc'],
                       aggfunc={'TTL Career $':np.sum,'Tailored $':np.sum,'Shoes $':np.sum,'Dress $':np.sum,'Basic $':np.sum,'Acc $':np.sum,
                                'Loc':len}
                      )
region = region[col1]
region['TTL Career Pen'] = region['TTL Career $'] / region['TTL Career $'].sum()
region['Tailored Pen'] = region['Tailored $'] / region['Tailored $'].sum()
region['Shoes Pen'] = region['Shoes $']/ region['Shoes $'].sum()
region['Dress Pen'] = region['Dress $'] / region['Dress $'].sum()
region['Basic Pen'] = region['Basic $'] / region['Basic $'].sum()
region['Acc Pen'] = region['Acc $'] / region['Acc $'].sum()
for x in col:
    region[x] = region[x].map("{:.2%}".format)
col3 = ['TTL Career $', 'Tailored $', 'Shoes $', 'Dress $', 'Basic $', 'Acc $',
       'TTL Career Pen','Loc', 'Tailored Pen','Loc' 'Shoes Pen', 'Dress Pen',
       'Basic Pen', 'Acc Pen']
region
# Out:
#                TTL Career $  Tailored $  Shoes $  Dress $  Basic $   Acc $  \
# REGION
# MID-ATLANTIC       $175,675     $71,269  $26,856  $34,497  $30,604 $12,448
# NEIGHBORHOOD        $86,956     $27,589  $15,083  $18,159  $18,333  $7,792
# NORTH CENTRAL      $167,398     $68,276  $26,655  $32,550  $27,592 $12,325
# NORTHEAST          $267,922     $94,549  $47,947  $49,206  $54,123 $22,097
# NORTHWEST          $129,281     $47,335  $22,993  $24,736  $24,538  $9,679
# SOUTH CENTRAL      $105,206     $40,777  $17,757  $19,615  $19,141  $7,917
# SOUTHEAST          $196,951     $74,098  $36,690  $36,133  $37,319 $12,711
# SOUTHWEST          $137,620     $45,189  $27,013  $25,577  $28,695 $11,146
#
#                Loc TTL Career Pen Tailored Pen Shoes Pen Dress Pen Basic Pen  \
# REGION
# MID-ATLANTIC    53         13.87%       15.19%    12.15%    14.35%    12.73%
# NEIGHBORHOOD   101          6.86%        5.88%     6.83%     7.55%     7.63%
# ...

# %% [markdown]
# #### From perspective of Region, Dress Furnishing has similar sales trend with Tailored.

# %%
col1 = ['TTL Career $','Tailored $','Shoes $','Dress $','Basic $','Acc $','Loc']
#col2 = ['A++','A+','A','B','C','D','E','F','G']
climate = Div19.pivot_table(index='CLIMATE',values=['TTL Career $','Tailored $','Shoes $','Dress $','Basic $','Acc $','Loc'],
                       aggfunc={'TTL Career $':np.sum,'Tailored $':np.sum,'Shoes $':np.sum,'Dress $':np.sum,'Basic $':np.sum,'Acc $':np.sum,
                                'Loc':len}
                      )
climate = climate[col1]
climate['TTL Career Pen'] = climate['TTL Career $'] / climate['TTL Career $'].sum()
climate['Tailored Pen'] = climate['Tailored $'] / climate['Tailored $'].sum()
climate['Shoes Pen'] = climate['Shoes $']/ climate['Shoes $'].sum()
climate['Dress Pen'] = climate['Dress $'] / climate['Dress $'].sum()
climate['Basic Pen'] = climate['Basic $'] / climate['Basic $'].sum()
climate['Acc Pen'] = climate['Acc $'] / climate['Acc $'].sum()
for x in col:
    climate[x] = climate[x].map("{:.2%}".format)
col3 = ['TTL Career $', 'Tailored $', 'Shoes $', 'Dress $', 'Basic $', 'Acc $',
       'TTL Career Pen','Loc', 'Tailored Pen','Loc' 'Shoes Pen', 'Dress Pen',
       'Basic Pen', 'Acc Pen']
climate
# Out:
#                      TTL Career $  Tailored $  Shoes $  Dress $  Basic $  \
# CLIMATE
# COLD                     $238,938     $94,759  $36,915  $48,013  $41,219
# COLD SUMMER               $22,490      $6,624   $4,671   $4,159   $5,187
# DESERT                    $28,652     $10,331   $5,001   $5,153   $5,937
# EXT COLD                  $55,044     $22,861   $7,179  $11,847   $9,103
# HOT                       $52,930     $20,129   $9,321  $10,159   $9,299
# NORMAL                   $392,556    $142,848  $69,213  $72,678  $76,660
# NORTHWEST                 $30,471     $11,634   $4,573   $6,126   $5,687
# SOUTHERN CALIFORNIA      $123,758     $41,302  $23,506  $23,650  $25,540
# TROPICAL                 $161,697     $58,018  $31,746  $29,173  $31,909
# WARM                      $68,284     $24,806  $13,271  $12,510  $12,703
# WARM SOUTH                $92,189     $35,770  $15,598  $17,005  $17,100
#
#                       Acc $  Loc TTL Career Pen Tailored Pen Shoes Pen  \
# ...

# %% [markdown]
# #### Again, Dress Furnishing has similar sales trend with Tailored in Climate Feature.
# #### Need to look an assortment of dress shirt and Neck tie seperately with Climate Cluster because they might have different sales pattern.

# %%
col1 = ['TTL Career $','Tailored $','Shoes $','Dress $','Basic $','Acc $','Loc']
#col2 = ['A++','A+','A','B','C','D','E','F','G']
life = Div19.pivot_table(index='LIFESTYLE',values=['TTL Career $','Tailored $','Shoes $','Dress $','Basic $','Acc $','Loc'],
                       aggfunc={'TTL Career $':np.sum,'Tailored $':np.sum,'Shoes $':np.sum,'Dress $':np.sum,'Basic $':np.sum,'Acc $':np.sum,
                                'Loc':len}
                      )
life = life[col1]
life['TTL Career Pen'] = life['TTL Career $'] / life['TTL Career $'].sum()
life['Tailored Pen'] = life['Tailored $'] / life['Tailored $'].sum()
life['Shoes Pen'] = life['Shoes $']/ life['Shoes $'].sum()
life['Dress Pen'] = life['Dress $'] / life['Dress $'].sum()
life['Basic Pen'] = life['Basic $'] / life['Basic $'].sum()
life['Acc Pen'] = life['Acc $'] / life['Acc $'].sum()
for x in col:
    life[x] = life[x].map("{:.2%}".format)
col3 = ['TTL Career $', 'Tailored $', 'Shoes $', 'Dress $', 'Basic $', 'Acc $',
       'TTL Career Pen','Loc', 'Tailored Pen','Loc' 'Shoes Pen', 'Dress Pen',
       'Basic Pen', 'Acc Pen']
life
# Out:
#               TTL Career $  Tailored $  Shoes $  Dress $  Basic $   Acc $  \
# LIFESTYLE
# CLASSIC           $258,946    $102,804  $38,323  $52,331  $46,524 $18,964
# FREESTYLE         $159,070     $57,182  $27,052  $32,392  $29,235 $13,209
# MODERN            $341,007    $139,099  $53,596  $63,308  $60,703 $24,301
# STYLE SETTER      $130,680     $49,244  $23,452  $25,090  $23,614  $9,281
# VIP               $377,306    $120,754  $78,572  $67,354  $80,267 $30,360
#
#               Loc TTL Career Pen Tailored Pen Shoes Pen Dress Pen Basic Pen  \
# LIFESTYLE
# CLASSIC       137         20.44%       21.92%    17.34%    21.76%    19.36%
# FREESTYLE     117         12.55%       12.19%    12.24%    13.47%    12.16%
# MODERN         89         26.91%       29.65%    24.25%    26.33%    25.26%
# STYLE SETTER   47         10.31%       10.50%    10.61%    10.43%     9.83%
# VIP           124         29.78%       25.74%    35.55%    28.01%    33.40%
#
#              Acc Pen
# LIFESTYLE
# ...

# %% [markdown]
# #### With assumption that Dress Furnishing has similar sales pattern with Tailored, The dress and Modern cluster has opportunities.

# %%
col1 = ['TTL Career $','Tailored $','Shoes $','Dress $','Basic $','Acc $','Loc']
#col2 = ['A++','A+','A','B','C','D','E','F','G']
customer = Div19.pivot_table(index='CUSTOMER SEGMENTS',values=['TTL Career $','Tailored $','Shoes $','Dress $','Basic $','Acc $','Loc'],
                       aggfunc={'TTL Career $':np.sum,'Tailored $':np.sum,'Shoes $':np.sum,'Dress $':np.sum,'Basic $':np.sum,'Acc $':np.sum,
                                'Loc':len}
                      )
customer = customer[col1]
customer['TTL Career Pen'] = customer['TTL Career $'] / customer['TTL Career $'].sum()
customer['Tailored Pen'] = customer['Tailored $'] / customer['Tailored $'].sum()
customer['Shoes Pen'] = customer['Shoes $']/ customer['Shoes $'].sum()
customer['Dress Pen'] = customer['Dress $'] / customer['Dress $'].sum()
customer['Basic Pen'] = customer['Basic $'] / customer['Basic $'].sum()
customer['Acc Pen'] = customer['Acc $'] / customer['Acc $'].sum()
for x in col:
    customer[x] = customer[x].map("{:.2%}".format)
col3 = ['TTL Career $', 'Tailored $', 'Shoes $', 'Dress $', 'Basic $', 'Acc $',
       'TTL Career Pen','Loc', 'Tailored Pen','Loc' 'Shoes Pen', 'Dress Pen',
       'Basic Pen', 'Acc Pen']
customer
# Out:
#                    TTL Career $  Tailored $  Shoes $  Dress $  Basic $  \
# CUSTOMER SEGMENTS
# Higher Value           $121,790     $42,454  $23,390  $22,195  $24,557
# Lower Value            $163,382     $62,640  $24,733  $33,212  $29,902
# Moderate Value         $981,838    $363,988 $172,871 $185,067 $185,885
#
#                     Acc $  Loc TTL Career Pen Tailored Pen Shoes Pen  \
# CUSTOMER SEGMENTS
# Higher Value       $9,194   38          9.61%        9.05%    10.58%
# Lower Value       $12,894  137         12.90%       13.35%    11.19%
# Moderate Value    $74,026  339         77.49%       77.60%    78.22%
#
#                   Dress Pen Basic Pen Acc Pen
# CUSTOMER SEGMENTS
# Higher Value          9.23%    10.22%   9.57%
# Lower Value          13.81%    12.44%  13.42%
# Moderate Value       76.96%    77.34%  77.02%

# %% [markdown]
# #### Could not find any distinguish sales pattern but need to look a assortment, price range, AUR, and markdown.

# %%
col1 = ['TTL Career $','Tailored $','Shoes $','Dress $','Basic $','Acc $','Loc']
#col2 = ['A++','A+','A','B','C','D','E','F','G']
store = Div19.pivot_table(index='STORE INITIATIVES',values=['TTL Career $','Tailored $','Shoes $','Dress $','Basic $','Acc $','Loc'],
                       aggfunc={'TTL Career $':np.sum,'Tailored $':np.sum,'Shoes $':np.sum,'Dress $':np.sum,'Basic $':np.sum,'Acc $':np.sum,
                                'Loc':len}
                      )
store = store[col1]
store['TTL Career Pen'] = store['TTL Career $'] / store['TTL Career $'].sum()
store['Tailored Pen'] = store['Tailored $'] / store['Tailored $'].sum()
store['Shoes Pen'] = store['Shoes $']/ store['Shoes $'].sum()
store['Dress Pen'] = store['Dress $'] / store['Dress $'].sum()
store['Basic Pen'] = store['Basic $'] / store['Basic $'].sum()
store['Acc Pen'] = store['Acc $'] / store['Acc $'].sum()
for x in col:
    store[x] = store[x].map("{:.2%}".format)
col3 = ['TTL Career $', 'Tailored $', 'Shoes $', 'Dress $', 'Basic $', 'Acc $',
       'TTL Career Pen','Loc', 'Tailored Pen','Loc' 'Shoes Pen', 'Dress Pen',
       'Basic Pen', 'Acc Pen']
store
# Out:
#                    TTL Career $  Tailored $  Shoes $  Dress $  Basic $  \
# STORE INITIATIVES
# FLAGSHIP               $147,653     $51,913  $29,529  $23,837  $30,386
# Growth50               $220,455     $86,344  $40,207  $40,927  $37,842
# N                      $553,049    $198,455  $91,086 $110,920 $108,187
# Next100                $345,852    $132,370  $60,173  $64,790  $63,929
#
#                     Acc $  Loc TTL Career Pen Tailored Pen Shoes Pen  \
# STORE INITIATIVES
# FLAGSHIP          $11,988   11         11.65%       11.07%    13.36%
# Growth50          $15,135   48         17.40%       18.41%    18.19%
# N                 $44,401  357         43.65%       42.31%    41.22%
# Next100           $24,591   98         27.30%       28.22%    27.23%
#
#                   Dress Pen Basic Pen Acc Pen
# STORE INITIATIVES
# FLAGSHIP              9.91%    12.64%  12.47%
# Growth50             17.02%    15.74%  15.75%
# N                    46.13%    45.01%  46.20%
# ...

# %% [markdown]
# #### As we seen before that Dress has opportutines and chanllege in top doors, It has same sales pattern here.
