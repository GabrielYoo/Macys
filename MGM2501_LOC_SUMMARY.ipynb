# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
pd.options.display.float_format = '${:,.0f}'.format
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
xls = pd.ExcelFile(r'C:\Users\Gabriel\PythonProjects\Macys\MGM2501\MGM2501 LOC.xlsx')
d464 = pd.read_excel(xls,'D464',index_col=False)
d522 = pd.read_excel(xls,'D522',index_col=False)
d523 = pd.read_excel(xls,'D523',index_col=False)
d525 = pd.read_excel(xls,'D525',index_col=False)
d544 = pd.read_excel(xls,'D544',index_col=False)
door = pd.read_excel(r'C:\Users\Gabriel\PythonProjects\Macys\door info.xlsx', index_col=False)
ttl = pd.concat([d464,d522,d523,d525,d544])
d464 = d464.merge(door,how='inner',on='Loc')
d522 = d522.merge(door,how='inner',on='Loc')
d523 = d523.merge(door,how='inner',on='Loc')
d525 = d525.merge(door,how='inner',on='Loc')
d544 = d544.merge(door,how='inner',on='Loc')

# %% [markdown]
# # D464

# %%
features = ['RegMDS','VOL GRP','CLIMATE','ASIAN_STRATEGY','BLACK_STRATEGY','LATINO_STRATEGY','CER','FLAGSHIP',
            'DOMESTIC_TOURIST_DOORS','INTERNATIONAL_TOURIST_DOORS','ALL_TOURIST_DOORS','WARM_WEATHER_STRATEGY',
            'SREGMDS','COMPETITOR_JCPENNEY','COMPETITOR_NORDSTROM','COMPETITOR_KOHLS','COMPETITOR_TJ_MAXX','ALL_DOOR_STRATEGY',
            'GROWTH50','STORE_BEHAVIORAL_RANGE','LIFESTYLE','SEARS_CLOUSER','JCP_CLOSURES','KHOLS_CLOSURES'
            ,'NORDSTROMS_CLOSURES','GROWTH_DOORS','DRESSBARN_CLOSURES','COMPETITOR_LT','MARKET SHARE OPPTY_NORDSTROM',
            'MARKET SHARE OPPTY_L&T','COMPETITOR_SEARS','NEIGHBORHOOD_PILOT_DRS','CENTRAL_ASIAN_STRATEGY',
            'EASTERN_ASIAN_STRATEGY','FOREVER21_CLOSURES','new_reg','NEIGHBORHOOD TRANSFER LOCATIONS']

df = d464.pivot_table(index='LIFESTYLE',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['TTL Sales 18 Pen'] = df['TTL Sales 18'] / (df['TTL Sales 18'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen Sales 18 Pen'] = (df['Replen Sales 18'] / (df['Replen Sales 18'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen','TTL Sales 18 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 18 Pen','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for a in col:
    df[a] = df[a].map(lambda n: '{:,.2%}'.format(n))

df=df[col1]
df
# Out:
#               TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# LIFESTYLE
# CLASSIC             $2,704           24.04%           -5.10%        $2,849
# FREESTYLE           $1,652           14.68%           -3.42%        $1,710
# MODERN              $2,924           25.99%           -7.58%        $3,164
# STYLE SETTER        $1,150           10.22%           -3.83%        $1,196
# VIP                 $2,819           25.06%          -10.83%        $3,162
# All                $11,249          100.00%           -6.88%       $12,080
#
#              TTL Sales 18 Pen  TTL Sales 17  TTL GRS REC 19  \
# LIFESTYLE
# CLASSIC                23.58%             0          $3,145
# FREESTYLE              14.16%             0          $2,104
# MODERN                 26.19%             0          $3,389
# STYLE SETTER            9.90%             0          $1,396
# VIP                    26.17%             0          $3,361
# ...

# %%
df = d464.pivot_table(index='RegMDS',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# RegMDS
# MID-ATLANTIC         $1,630           14.49%           -5.81%        $1,731
# NEIGHBORHOOD           $975            8.66%           -3.02%        $1,005
# NORTH CENTRAL        $1,540           13.69%           -6.81%        $1,653
# NORTHEAST            $2,147           19.09%           -9.61%        $2,376
# NORTHWEST            $1,349           11.99%           -7.55%        $1,459
# SOUTH CENTRAL          $963            8.56%           -6.90%        $1,034
# SOUTHEAST            $1,367           12.15%           -6.86%        $1,468
# SOUTHWEST            $1,278           11.36%           -5.73%        $1,355
# All                 $11,249          100.00%           -6.88%       $12,080
#
#                TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# RegMDS
# MID-ATLANTIC              0          $1,802             13.46%
# ...

# %%
df = d464.pivot_table(index='CLIMATE',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                      TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  \
# CLIMATE
# COLD                       $2,310           20.54%           -5.26%
# COLD SUMMER                  $216            1.92%           -5.78%
# DESERT                       $240            2.13%           -3.91%
# EXT COLD                     $606            5.39%           -2.35%
# HOT                          $494            4.39%           -7.38%
# NORMAL                     $3,300           29.34%           -8.84%
# NORTHWEST                    $340            3.03%           -5.80%
# SOUTHERN CALIFORNIA        $1,157           10.29%           -5.57%
# TROPICAL                     $992            8.82%           -4.71%
# WARM                         $682            6.07%          -10.42%
# WARM SOUTH                   $911            8.10%           -8.89%
# All                       $11,249          100.00%           -6.88%
#
#                      TTL Sales 18  TTL Sales 17  TTL GRS REC 19  \
# ...

# %%
df = d464.pivot_table(index='new_reg',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# new_reg
# MID-ATLANTIC         $1,630           14.49%           -5.81%        $1,731
# NEIGHBORHOOD           $975            8.66%           -3.02%        $1,005
# NORTH CENTRAL        $1,540           13.69%           -6.81%        $1,653
# NORTHEAST            $2,147           19.09%           -9.61%        $2,376
# NORTHWEST            $1,349           11.99%           -7.55%        $1,459
# SOUTH CENTRAL          $963            8.56%           -6.90%        $1,034
# SOUTHEAST            $1,367           12.15%           -6.86%        $1,468
# SOUTHWEST            $1,278           11.36%           -5.73%        $1,355
# All                 $11,249          100.00%           -6.88%       $12,080
#
#                TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# new_reg
# MID-ATLANTIC              0          $1,802             13.46%
# ...

# %%
df = d464.pivot_table(index='GY_Spring_Cluster_D464',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                         TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  \
# GY_Spring_Cluster_D464
# A                               $283            2.52%          -23.94%
# B                             $1,436           12.77%           -5.34%
# C                             $1,077            9.58%           -7.84%
# D                             $1,100            9.78%           -6.87%
# E                             $1,651           14.67%           -5.36%
# F                             $1,711           15.21%           -8.06%
# G                             $1,716           15.25%           -4.86%
# H                             $1,182           10.50%           -8.22%
# I                             $1,093            9.72%           -4.51%
# J                                 $0            0.00%         -100.00%
# All                          $11,249          100.00%           -6.88%
#
#                         TTL Sales 18  TTL Sales 17  TTL GRS REC 19  \
# ...

# %%
df = d464.pivot_table(index='Loc',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df.sort_values(by='TTL Sales 19 Pen',ascending=False)
# Out:
#      TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# Loc
# 3            $283            5.04%          -23.94%          $372
# 53           $111            1.98%           -1.94%          $113
# 428           $82            1.45%           -0.87%           $82
# 76            $77            1.36%            1.20%           $76
# 75            $75            1.34%           -8.87%           $83
# 1             $73            1.29%          -12.57%           $83
# 523           $70            1.24%            7.91%           $64
# 7             $66            1.17%           -5.63%           $69
# 95            $66            1.17%            1.37%           $65
# 173           $65            1.16%           -6.06%           $70
# 358           $64            1.14%          -19.55%           $80
# 776           $63            1.11%            4.03%           $60
# 31            $62            1.11%            9.96%           $57
# ...

# %% [markdown]
# # D522

# %%
df = d522.pivot_table(index='LIFESTYLE',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#               TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# LIFESTYLE
# CLASSIC             $2,078           25.37%          -17.59%        $2,521
# FREESTYLE           $1,180           14.40%          -21.05%        $1,494
# MODERN              $1,696           20.71%          -17.25%        $2,049
# STYLE SETTER          $866           10.58%          -15.08%        $1,020
# VIP                 $2,370           28.94%          -17.52%        $2,873
# All                 $8,189          100.00%          -17.76%        $9,958
#
#               TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# LIFESTYLE
# CLASSIC             $7,802          $3,151             26.21%
# FREESTYLE           $4,871          $1,742             14.49%
# MODERN              $6,830          $2,503             20.81%
# STYLE SETTER        $3,095          $1,289             10.72%
# VIP                 $9,075          $3,339             27.77%
# ...

# %%
df = d522.pivot_table(index='RegMDS',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# RegMDS
# MID-ATLANTIC         $1,266           15.46%          -15.62%        $1,501
# NEIGHBORHOOD           $752            9.18%          -24.21%          $992
# NORTH CENTRAL          $935           11.42%          -14.14%        $1,089
# NORTHEAST            $2,013           24.58%          -10.04%        $2,238
# NORTHWEST              $782            9.55%          -24.10%        $1,030
# SOUTH CENTRAL          $763            9.32%          -19.08%          $943
# SOUTHEAST              $793            9.68%          -24.79%        $1,054
# SOUTHWEST              $885           10.81%          -20.33%        $1,112
# All                  $8,189          100.00%          -17.76%        $9,958
#
#                TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# RegMDS
# MID-ATLANTIC         $4,408          $1,831             15.22%
# ...

# %%
df = d522.pivot_table(index='CLIMATE',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                      TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  \
# CLIMATE
# COLD                       $1,621           19.79%          -14.85%
# COLD SUMMER                  $122            1.49%          -25.75%
# DESERT                       $187            2.28%          -17.50%
# EXT COLD                     $368            4.49%          -17.09%
# HOT                          $421            5.14%          -21.07%
# NORMAL                     $2,870           35.04%          -13.55%
# NORTHWEST                    $225            2.75%          -12.93%
# SOUTHERN CALIFORNIA          $859           10.49%          -18.16%
# TROPICAL                     $585            7.15%          -25.29%
# WARM                         $414            5.06%          -27.12%
# WARM SOUTH                   $518            6.32%          -26.81%
# All                        $8,189          100.00%          -17.76%
#
#                      TTL Sales 18  TTL Sales 17  TTL GRS REC 19  \
# ...

# %%
df = d522.pivot_table(index='new_reg',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# new_reg
# MID-ATLANTIC         $1,266           15.46%          -15.62%        $1,501
# NEIGHBORHOOD           $752            9.18%          -24.21%          $992
# NORTH CENTRAL          $935           11.42%          -14.14%        $1,089
# NORTHEAST            $2,013           24.58%          -10.04%        $2,238
# NORTHWEST              $782            9.55%          -24.10%        $1,030
# SOUTH CENTRAL          $763            9.32%          -19.08%          $943
# SOUTHEAST              $793            9.68%          -24.79%        $1,054
# SOUTHWEST              $885           10.81%          -20.33%        $1,112
# All                  $8,189          100.00%          -17.76%        $9,958
#
#                TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# new_reg
# MID-ATLANTIC         $4,408          $1,831             15.22%
# ...

# %%
df = d522.pivot_table(index='GY_Spring_Cluster_D522',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                         TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  \
# GY_Spring_Cluster_D522
# A                               $259            3.17%           -9.63%
# B                               $881           10.76%            0.91%
# C                               $738            9.01%           -9.65%
# D                               $821           10.02%          -17.56%
# E                             $1,186           14.48%          -12.81%
# F                             $1,225           14.96%          -16.69%
# G                             $1,210           14.78%          -19.35%
# H                               $959           11.71%          -22.26%
# I                               $907           11.08%          -35.89%
# J                                 $3            0.03%          -52.61%
# All                           $8,189          100.00%          -17.76%
#
#                         TTL Sales 18  TTL Sales 17  TTL GRS REC 19  \
# ...

# %%
df = d522.pivot_table(index='Loc',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df.sort_values(by='TTL Sales 19 Pen',ascending=False)
# Out:
#      TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# Loc
# 53           $169            4.13%            7.47%          $157
# 173          $135            3.29%           11.25%          $121
# 6             $92            2.25%           -5.17%           $97
# 1             $92            2.24%           -2.10%           $94
# 36            $92            2.24%           -0.29%           $92
# 3             $90            2.20%          -30.41%          $129
# 7             $83            2.02%            0.92%           $82
# 75            $78            1.91%           15.04%           $68
# 76            $78            1.89%           -4.81%           $81
# 19            $74            1.80%          -11.45%           $83
# 8             $60            1.46%           -2.08%           $61
# 533           $57            1.40%           10.65%           $52
# 68            $56            1.36%            0.67%           $55
# ...

# %%
ds = ['dsRegMDS','dsVOL GRP','dsCLIMATE','dsASIAN_STRATEGY','dsBLACK_STRATEGY','dsLATINO_STRATEGY','dsCER','dsFLAGSHIP',
            'dsDOMESTIC_TOURIST_DOORS','dsINTERNATIONAL_TOURIST_DOORS','dsALL_TOURIST_DOORS','dsWARM_WEATHER_STRATEGY',
            'dsSREGMDS','dsCOMPETITOR_JCPENNEY','dsCOMPETITOR_NORDSTROM','dsCOMPETITOR_KOHLS','dsCOMPETITOR_TJ_MAXX',
            'dsALL_DOOR_STRATEGY','dsGROWTH50','dsSTORE_BEHAVIORAL_RANGE','dsLIFESTYLE','dsSEARS_CLOUSER','dsJCP_CLOSURES',
            'dsKHOLS_CLOSURES','dsNORDSTROMS_CLOSURES','dsGROWTH_DOORS','dsDRESSBARN_CLOSURES','dsCOMPETITOR_LT',
            'dsMARKET SHARE OPPTY_NORDSTROM','dsMARKET SHARE OPPTY_L&T','dsCOMPETITOR_SEARS','dsNEIGHBORHOOD_PILOT_DRS',
            'dsCENTRAL_ASIAN_STRATEGY','dsEASTERN_ASIAN_STRATEGY','dsFOREVER21_CLOSURES','dsnew_reg','dsNEIGHBORHOOD TRANSFER LOCATIONS']

# %% [markdown]
# # D523

# %%
df = d523.pivot_table(index='LIFESTYLE',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#               TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# LIFESTYLE
# CLASSIC             $9,730           20.85%           -3.82%       $10,116
# FREESTYLE           $4,661            9.99%           -2.66%        $4,788
# MODERN             $14,414           30.90%           -0.70%       $14,516
# STYLE SETTER        $4,737           10.15%            0.40%        $4,718
# VIP                $13,112           28.11%           -5.18%       $13,829
# All                $46,654          100.00%           -2.74%       $47,968
#
#               TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# LIFESTYLE
# CLASSIC            $10,407         $17,953             21.53%
# FREESTYLE           $4,852          $8,193              9.82%
# MODERN             $15,451         $25,458             30.53%
# STYLE SETTER        $4,731          $8,477             10.16%
# VIP                $14,299         $23,319             27.96%
# ...

# %%
df = d523.pivot_table(index='RegMDS',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# RegMDS
# MID-ATLANTIC         $7,022           15.05%           -2.99%        $7,238
# NEIGHBORHOOD         $2,456            5.26%           -6.65%        $2,631
# NORTH CENTRAL        $6,734           14.43%            1.06%        $6,663
# NORTHEAST           $10,470           22.44%           -4.87%       $11,005
# NORTHWEST            $4,650            9.97%           -4.37%        $4,862
# SOUTH CENTRAL        $3,789            8.12%           -0.15%        $3,795
# SOUTHEAST            $6,323           13.55%           -4.63%        $6,630
# SOUTHWEST            $5,211           11.17%            1.30%        $5,144
# All                 $46,654          100.00%           -2.74%       $47,968
#
#                TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# RegMDS
# MID-ATLANTIC         $7,355         $12,449             14.93%
# ...

# %%
df = d523.pivot_table(index='CLIMATE',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                      TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  \
# CLIMATE
# COLD                       $9,327           19.99%           -0.27%
# COLD SUMMER                  $826            1.77%          -14.05%
# DESERT                       $931            2.00%            1.24%
# EXT COLD                   $2,299            4.93%            1.45%
# HOT                        $1,984            4.25%            0.46%
# NORMAL                    $15,096           32.36%           -5.21%
# NORTHWEST                  $1,055            2.26%            1.58%
# SOUTHERN CALIFORNIA        $4,888           10.48%            1.93%
# TROPICAL                   $4,768           10.22%           -3.78%
# WARM                       $2,388            5.12%           -3.51%
# WARM SOUTH                 $3,093            6.63%           -6.42%
# All                       $46,654          100.00%           -2.74%
#
#                      TTL Sales 18  TTL Sales 17  TTL GRS REC 19  \
# ...

# %%
df = d523.pivot_table(index='new_reg',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# new_reg
# MID-ATLANTIC         $7,022           15.05%           -2.99%        $7,238
# NEIGHBORHOOD         $2,456            5.26%           -6.65%        $2,631
# NORTH CENTRAL        $6,734           14.43%            1.06%        $6,663
# NORTHEAST           $10,470           22.44%           -4.87%       $11,005
# NORTHWEST            $4,650            9.97%           -4.37%        $4,862
# SOUTH CENTRAL        $3,789            8.12%           -0.15%        $3,795
# SOUTHEAST            $6,323           13.55%           -4.63%        $6,630
# SOUTHWEST            $5,211           11.17%            1.30%        $5,144
# All                 $46,654          100.00%           -2.74%       $47,968
#
#                TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# new_reg
# MID-ATLANTIC         $7,355         $12,449             14.93%
# ...

# %%
df = d523.pivot_table(index='GY_Spring_Cluster_D523',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                         TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  \
# GY_Spring_Cluster_D523
# A                             $2,409            5.16%          -14.98%
# B                             $4,345            9.31%           -5.29%
# C                             $5,285           11.33%            3.04%
# D                             $3,949            8.46%           -2.74%
# E                             $7,023           15.05%           -1.05%
# F                             $7,067           15.15%           -0.50%
# G                             $7,388           15.84%           -0.30%
# H                             $4,825           10.34%           -5.50%
# I                             $4,362            9.35%           -5.96%
# J                                 $1            0.00%          -84.20%
# All                          $46,654          100.00%           -2.74%
#
#                         TTL Sales 18  TTL Sales 17  TTL GRS REC 19  \
# ...

# %%
df = d523.pivot_table(index='Loc',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df.sort_values(by='TTL Sales 19',ascending=False)
# Out:
#      TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# Loc
# 3          $2,409           10.33%          -14.98%        $2,833
# 53           $615            2.64%            7.50%          $572
# 776          $582            2.50%           -1.04%          $588
# 769          $493            2.11%           -6.28%          $526
# 428          $469            2.01%          -21.33%          $596
# 1            $418            1.79%           -1.97%          $426
# 76           $408            1.75%            0.61%          $405
# 810          $379            1.62%          -10.06%          $421
# 523          $374            1.60%           -3.67%          $388
# 358          $373            1.60%            9.05%          $342
# 687          $373            1.60%            0.32%          $372
# 75           $369            1.58%            0.22%          $368
# 23           $361            1.55%            2.62%          $352
# ...

# %% [markdown]
# # D525

# %%
df = d525.pivot_table(index='LIFESTYLE',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#               TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# LIFESTYLE
# CLASSIC             $5,915           24.41%           -7.76%        $6,412
# FREESTYLE           $3,068           12.66%           -5.38%        $3,242
# MODERN              $6,707           27.68%           -9.07%        $7,376
# STYLE SETTER        $2,421            9.99%           -6.14%        $2,579
# VIP                 $6,116           25.24%          -12.00%        $6,950
# All                $24,226           99.99%           -8.78%       $26,559
#
#               TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# LIFESTYLE
# CLASSIC             $9,912          $5,021             24.59%
# FREESTYLE           $5,215          $2,724             13.34%
# MODERN             $10,929          $5,441             26.65%
# STYLE SETTER        $3,922          $2,050             10.04%
# VIP                $10,650          $5,180             25.37%
# ...

# %%
df = d525.pivot_table(index='RegMDS',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# RegMDS
# MID-ATLANTIC         $3,753           15.49%           -8.49%        $4,102
# NEIGHBORHOOD         $1,815            7.49%           -8.29%        $1,979
# NORTH CENTRAL        $3,715           15.33%           -6.51%        $3,974
# NORTHEAST            $5,398           22.28%           -9.98%        $5,997
# NORTHWEST            $2,357            9.73%          -11.48%        $2,663
# SOUTH CENTRAL        $1,813            7.48%           -5.68%        $1,922
# SOUTHEAST            $2,984           12.32%           -8.77%        $3,271
# SOUTHWEST            $2,395            9.89%           -9.71%        $2,653
# All                 $24,226           99.99%           -8.78%       $26,559
#
#                TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# RegMDS
# MID-ATLANTIC         $6,143          $3,081             15.09%
# ...

# %%
df = d525.pivot_table(index='CLIMATE',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                      TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  \
# CLIMATE
# COLD                       $5,391           22.25%           -5.52%
# COLD SUMMER                  $333            1.37%          -25.54%
# DESERT                       $480            1.98%           -6.53%
# EXT COLD                   $1,351            5.58%           -5.27%
# HOT                          $916            3.78%           -6.09%
# NORMAL                     $7,920           32.69%          -10.82%
# NORTHWEST                    $585            2.42%           -6.80%
# SOUTHERN CALIFORNIA        $2,194            9.06%           -9.65%
# TROPICAL                   $2,133            8.80%           -8.92%
# WARM                       $1,184            4.89%          -10.58%
# WARM SOUTH                 $1,742            7.19%           -7.66%
# All                       $24,226           99.99%           -8.78%
#
#                      TTL Sales 18  TTL Sales 17  TTL GRS REC 19  \
# ...

# %%
df = d525.pivot_table(index='new_reg',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# new_reg
# MID-ATLANTIC         $3,753           15.49%           -8.49%        $4,102
# NEIGHBORHOOD         $1,815            7.49%           -8.29%        $1,979
# NORTH CENTRAL        $3,715           15.33%           -6.51%        $3,974
# NORTHEAST            $5,398           22.28%           -9.98%        $5,997
# NORTHWEST            $2,357            9.73%          -11.48%        $2,663
# SOUTH CENTRAL        $1,813            7.48%           -5.68%        $1,922
# SOUTHEAST            $2,984           12.32%           -8.77%        $3,271
# SOUTHWEST            $2,395            9.89%           -9.71%        $2,653
# All                 $24,226           99.99%           -8.78%       $26,559
#
#                TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# new_reg
# MID-ATLANTIC         $6,143          $3,081             15.09%
# ...

# %%
df = d525.pivot_table(index='GY_Spring_Cluster_D525',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                         TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  \
# GY_Spring_Cluster_D525
# A                               $980            4.04%          -23.18%
# B                             $2,881           11.89%           -8.52%
# C                             $2,476           10.22%          -11.69%
# D                             $2,307            9.52%           -6.19%
# E                             $3,772           15.57%           -9.37%
# F                             $3,777           15.59%           -5.86%
# G                             $3,519           14.52%           -8.21%
# H                             $2,360            9.74%           -6.35%
# I                             $2,160            8.92%           -7.88%
# J                                 $0            0.00%         -102.05%
# All                          $24,226           99.99%           -8.78%
#
#                         TTL Sales 18  TTL Sales 17  TTL GRS REC 19  \
# ...

# %%
df = d525.pivot_table(index='Loc',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df.sort_values(by='TTL Sales 19 Pen',ascending=False)
# Out:
#      TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# Loc
# 3            $980            8.09%          -23.18%        $1,275
# 53           $314            2.59%           -4.76%          $330
# 75           $199            1.64%            1.44%          $196
# 173          $182            1.51%           -4.07%          $190
# 7            $183            1.51%           -9.26%          $201
# 76           $180            1.49%          -15.91%          $214
# 23           $177            1.46%           -4.83%          $186
# 776          $174            1.44%           -4.06%          $181
# 8            $170            1.40%           -2.15%          $174
# 730          $157            1.30%          -10.81%          $176
# 33           $147            1.22%           -7.27%          $159
# 1            $147            1.21%           -6.61%          $157
# 769          $145            1.20%          -18.03%          $177
# ...

# %% [markdown]
# # D544

# %%
df = d544.pivot_table(index='LIFESTYLE',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#               TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# LIFESTYLE
# CLASSIC             $5,505           22.68%            6.65%        $5,161
# FREESTYLE           $3,851           15.87%            9.68%        $3,512
# MODERN              $5,490           22.62%           -2.11%        $5,608
# STYLE SETTER        $2,304            9.49%           -0.72%        $2,321
# VIP                 $7,119           29.34%            5.65%        $6,739
# All                $24,269          100.00%            3.98%       $23,340
#
#               TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# LIFESTYLE
# CLASSIC                  0          $6,796             22.69%
# FREESTYLE                0          $4,771             15.93%
# MODERN                   0          $6,804             22.72%
# STYLE SETTER             0          $2,977              9.94%
# VIP                      0          $8,605             28.73%
# ...

# %%
df = d544.pivot_table(index='RegMDS',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# RegMDS
# MID-ATLANTIC         $3,100           12.78%            3.26%        $3,002
# NEIGHBORHOOD         $2,434           10.03%           14.21%        $2,131
# NORTH CENTRAL        $2,782           11.46%            3.39%        $2,691
# NORTHEAST            $4,564           18.81%            1.03%        $4,518
# NORTHWEST            $2,969           12.23%           -1.74%        $3,022
# SOUTH CENTRAL        $2,344            9.66%            7.81%        $2,175
# SOUTHEAST            $3,226           13.29%           10.99%        $2,907
# SOUTHWEST            $2,849           11.74%           -1.59%        $2,894
# All                 $24,269          100.00%            3.98%       $23,340
#
#                TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# RegMDS
# MID-ATLANTIC              0          $3,822             12.76%
# ...

# %%
df = d544.pivot_table(index='CLIMATE',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                      TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  \
# CLIMATE
# COLD                       $4,437           18.28%            5.74%
# COLD SUMMER                  $517            2.13%           -8.00%
# DESERT                       $607            2.50%            3.75%
# EXT COLD                   $1,129            4.65%            4.44%
# HOT                        $1,247            5.14%            8.85%
# NORMAL                     $6,937           28.58%            1.87%
# NORTHWEST                    $756            3.12%           -0.19%
# SOUTHERN CALIFORNIA        $2,557           10.54%           -3.35%
# TROPICAL                   $2,403            9.90%           12.08%
# WARM                       $1,573            6.48%            1.85%
# WARM SOUTH                 $2,107            8.68%           12.70%
# All                       $24,269          100.00%            3.98%
#
#                      TTL Sales 18  TTL Sales 17  TTL GRS REC 19  \
# ...

# %%
df = d544.pivot_table(index='new_reg',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# new_reg
# MID-ATLANTIC         $3,100           12.78%            3.26%        $3,002
# NEIGHBORHOOD         $2,434           10.03%           14.21%        $2,131
# NORTH CENTRAL        $2,782           11.46%            3.39%        $2,691
# NORTHEAST            $4,564           18.81%            1.03%        $4,518
# NORTHWEST            $2,969           12.23%           -1.74%        $3,022
# SOUTH CENTRAL        $2,344            9.66%            7.81%        $2,175
# SOUTHEAST            $3,226           13.29%           10.99%        $2,907
# SOUTHWEST            $2,849           11.74%           -1.59%        $2,894
# All                 $24,269          100.00%            3.98%       $23,340
#
#                TTL Sales 17  TTL GRS REC 19 TTL GRS REC 19 Pen  \
# new_reg
# MID-ATLANTIC              0          $3,822             12.76%
# ...

# %%
df = d544.pivot_table(index='GY_Spring_Cluster_D544',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum,margins=True)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df
# Out:
#                         TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  \
# GY_Spring_Cluster_D544
# A                               $723            2.98%          -11.96%
# B                             $2,467           10.16%           -1.52%
# C                             $2,097            8.64%           -4.66%
# D                             $2,292            9.44%            2.51%
# E                             $3,462           14.26%            1.71%
# F                             $3,668           15.12%            1.48%
# G                             $3,961           16.32%            8.74%
# H                             $2,807           11.57%           11.22%
# I                             $2,793           11.51%           16.65%
# J                                 $0            0.00%          -43.65%
# All                          $24,269          100.00%            3.98%
#
#                         TTL Sales 18  TTL Sales 17  TTL GRS REC 19  \
# ...

# %%
df = d544.pivot_table(index='Loc',values=['TTL Sales 19','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 18',
                                                  'TTL GRS REC 17','Replen Sales 19','Replen Sales 18','Replen Sales 17',
                                                 'Replen GRS REC 19','Replen GRS REC 18','Replen GRS REC 17','Store Sales 19',
                                                 'Store Sales 18','Store Sales 17']
                        ,aggfunc=np.sum)
df['TTL Sales 18 Var'] = (df['TTL Sales 19'] - df['TTL Sales 18']) / df['TTL Sales 18']
df['TTL Sales 19 Pen'] = df['TTL Sales 19'] / (df['TTL Sales 19'].sum()/2)
df['Replen Sales 18 Var'] = (df['Replen Sales 19']- df['Replen Sales 18']) / df['TTL Sales 18']
df['Replen Sales 19 Pen'] = (df['Replen Sales 19'] / (df['Replen Sales 19'].sum()/2))
df['Replen % of TTL 19'] = (df['Replen Sales 19']/ df['TTL Sales 19'])
df['Replen % of TTL 18'] = (df['Replen Sales 18']/ df['TTL Sales 18'])
df['Replen % of TTL 17'] = (df['Replen Sales 17']/ df['TTL Sales 17'])
df['TTL GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['TTL GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df['Replen GRS REC 18 Var'] = (df['TTL GRS REC 19'] - df['TTL GRS REC 18']) / df['TTL GRS REC 18']
df['Replen GRS REC 19 Pen'] = (df['TTL GRS REC 19'] / (df['TTL GRS REC 19'].sum()/2))
df = df.fillna(0)
#df = df.drop(['N'], axis=0)
col = ['TTL Sales 18 Var','TTL Sales 19 Pen','TTL GRS REC 18 Var','TTL GRS REC 19 Pen','Replen Sales 18 Var','Replen Sales 19 Pen',
      'Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 18 Var','Replen GRS REC 19 Pen']
col1 = ['TTL Sales 19','TTL Sales 19 Pen','TTL Sales 18 Var','TTL Sales 18','TTL Sales 17','TTL GRS REC 19','TTL GRS REC 19 Pen',
       'TTL GRS REC 18 Var','TTL GRS REC 18','TTL GRS REC 17','Replen Sales 19','Replen Sales 19 Pen','Replen Sales 18 Var',
       'Replen Sales 18','Replen Sales 17','Replen % of TTL 19','Replen % of TTL 18','Replen % of TTL 17','Replen GRS REC 19',
       'Replen GRS REC 19 Pen','Replen GRS REC 18 Var','Replen GRS REC 18','Replen GRS REC 17']
for x in col:
    df[x] = df[x].map("{:.2%}".format)
df = df[col1]
df.sort_values(by='TTL Sales 19 Pen',ascending=False)
# Out:
#      TTL Sales 19 TTL Sales 19 Pen TTL Sales 18 Var  TTL Sales 18  \
# Loc
# 3            $723            5.96%          -11.96%          $821
# 53           $194            1.60%           -3.68%          $201
# 173          $180            1.48%           15.52%          $156
# 1            $162            1.34%            7.27%          $151
# 19           $161            1.33%            6.65%          $151
# 75           $161            1.33%           -4.11%          $168
# 76           $156            1.29%           -1.85%          $159
# 6            $152            1.25%            7.42%          $142
# 358          $140            1.16%          -10.00%          $156
# 428          $139            1.14%          -26.71%          $189
# 31           $127            1.05%            5.48%          $120
# 686          $126            1.04%            1.20%          $125
# 8            $123            1.01%            4.52%          $117
# ...
